# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions

# %%
model=ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import numpy as np

# %%
img_path='/content/white-bread.webp'
img_path2='/content/cat.webp'
img_path3='/content/lib.jpg'

# %%
img=image.load_img(img_path,target_size=(224,224))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

img1=image.load_img(img_path2,target_size=(224,224))
x1=image.img_to_array(img1)
x1=np.expand_dims(x1,axis=0)
x1=preprocess_input(x1)

img2=image.load_img(img_path3,target_size=(224,224))
x2=image.img_to_array(img2)
x2=np.expand_dims(x2,axis=0)
x2=preprocess_input(x2)

# %%
pred=model.predict(x)
print('Predicted :',decode_predictions(pred,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# Predicted : [('n04270147', 'spatula', np.float32(0.41271085)), ('n07684084', 'French_loaf', np.float32(0.11764827)), ('n12144580', 'corn', np.float32(0.058086693))]

# %%
pred=model.predict(x1)
print('Predicted :',decode_predictions(pred,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Predicted : [('n02123159', 'tiger_cat', np.float32(0.34641883)), ('n02123045', 'tabby', np.float32(0.1448284)), ('n02124075', 'Egyptian_cat', np.float32(0.12704502))]

# %%
pred=model.predict(x2)
print('Predicted :',decode_predictions(pred,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Predicted : [('n03661043', 'library', np.float32(0.89385116)), ('n02871525', 'bookshop', np.float32(0.08982173)), ('n02870880', 'bookcase', np.float32(0.014592477))]
